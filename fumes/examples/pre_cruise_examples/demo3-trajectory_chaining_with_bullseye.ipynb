# %%
# %load_ext autoreload
# %autoreload 2

# %%
"""Joins a spatiotemporal world with a chained lawnmower trajectory.

Example parameters can be modified at the start of the file.

Example usage (within the fumes environment):
    python fumes/examples/traj_chaining_bullseye.py
"""

import numpy as np
import matplotlib.pyplot as plt

from fumes.environment import Bullseye
from fumes.environment.utils import xcoord_circle, ycoord_circle

from fumes.trajectory import Lawnmower, Spiral
from fumes.planner import TrajectoryOpt, TrajectoryChain, \
    LawnSpiralGeneratorFlexible, LawnSpiralWithStartGeneratorFlexible

from fumes.model import FullyObs
from fumes.robot import OfflineRobot
from fumes.simulator import Simulator

from fumes.reward import SampleValues

from fumes.environment import Extent
from fumes.utils import tic, toc

import pdb

# %%
# Parameters
experiment_name = "traj_opt_chain_soft_origin6"

# Trajectory params
traj_type = "lawnmower"  # type of fixed trajectory
resolution = 5  # lawnmower resolution (in meters)
time_resolution = 3600  # time resolution (in seconds)

# Environment params
nx = 500  # environment x width (in meters)
ny = 500  # environment y height (in meters)

# Simulation params
t0 = 0.0  # initial time
duration = 12 * 3600.  # duration (in seconds)

# Robot params
vel = 0.5  # robot velocity (in meters/second)
samp_dist = 0.5  # distance between samples (in meters)
com_window = 120  # communication window (in seconds)
altitude = 0.0

# %%
# Create the environment
extent = Extent(xrange=(0., 500.), xres=100, yrange=(0., 500.), yres=100)
environment = Bullseye(extent, nx, ny, nx, ny, xcoord_circle, ycoord_circle,
                       l=0.01, A=1.0)

# Create a fully observeable model
model = FullyObs(extent, environment)

# Reward function
reward = SampleValues(
    sampling_params={"samp_dist": samp_dist},
    is_cost=True)


planners = []
budget = time_resolution * vel  # distance budget per leg
for start_time in np.arange(0, duration, step=time_resolution):
    # Create the base trajectory generator object with a temporary start_point
    # We will reset this later in the chaining process.
    traj_generator = LawnSpiralWithStartGeneratorFlexible(
        t0=start_time, vel=vel, alt=altitude, start_point=(0., 0.), 
        traj_type=traj_type, res=resolution)

    # Get predicted environment maxima
    xm, ym = model.get_maxima(start_time)
    
    # Create planner
    planners.append(TrajectoryOpt(
        model,
        traj_generator,
        reward,
        x0=(75., 75., 0., xm, ym),  # (lh, lw, rot, origin_x, origin_y)
        param_bounds=[(20., 100), (20., 100.), (-360., 360.), (0., 500.), (0., 500.)],        
        param_names={"lh": 0, "lw": 1, "rot": 2, "origin_x": 3, "origin_y": 4},        
        budget=budget,
        limits=[0., 500., 0., 500.],
        max_iters=None
    ))

planner = TrajectoryChain(planners=planners)

# %%
##################################################
# Get trajectory to execute
##################################################
print("Getting trajectory...")
tic()
plan_opt = planner.get_plan()
toc()
# Out:
# Getting trajectory...
# Planning chain 0 of 12 at time 0.0
# Adding budget constraint.
# Adding safety boundary constraint.
# Adding parameter bounds constraint.
# n:1	 Value:-17847783.77358003
# -elapsed time: 0.131 (s)
# n:2	 Value:-17847783.77358003
# -elapsed time: 0.124 (s)
# n:3	 Value:-17847783.77358003
# -elapsed time: 0.12 (s)
# n:4	 Value:-17847783.77358003
# -elapsed time: 0.118 (s)
# n:6	 Value:-17847783.77358003
# -elapsed time: 0.131 (s)
# n:7	 Value:-17847783.77358003
# -elapsed time: 0.114 (s)
# n:8	 Value:-17847783.77358003
# -elapsed time: 0.113 (s)
# n:9	 Value:-17847783.77358003
# -elapsed time: 0.113 (s)
# n:11	 Value:-17847783.77358003
# -elapsed time: 0.116 (s)
# n:12	 Value:-17848865.00225035
# -elapsed time: 0.137 (s)
# n:13	 Value:-17848973.41266882
# -elapsed time: 0.131 (s)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/dh/1dpvfgks4_n59262c0trj0jr0000gn/T/ipykernel_73168/1793360522.py in <module>
#       4 print("Getting trajectory...")
#       5 tic()
# ----> 6 plan_opt = planner.get_plan()
#       7 toc()
#
# ~/content/rrg/src/planning/fumes/fumes/planner/trajectory_chain.py in get_plan(self)
#      52             # Get the next trajectory in the chain
#      53             traj_chain.append(planner.get_plan(soft_origin=soft_origin,
# ---> 54                                                soft_com=soft_com))
#      55
#      56             # Update the soft origin
#
# ~/content/rrg/src/planning/fumes/fumes/planner/trajectory_opt.py in get_plan(self, soft_origin, soft_com)
#     152                 constraints=con,
#     153                 method=self.method,
# --> 154                 callback=self._callback)
#     155         elif self.method == "basinhopping":
#     156             res = optimize.basinhopping(
#
# ~/.local/share/virtualenvs/fumes-JfS6j1s-/lib/python3.7/site-packages/scipy/optimize/_minimize.py in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     634         return _minimize_trustregion_constr(fun, x0, args, jac, hess, hessp,
#     635                                             bounds, constraints,
# --> 636                                             callback=callback, **options)
#     637     elif meth == 'dogleg':
#     638         return _minimize_dogleg(fun, x0, args, jac, hess,
#
# ~/.local/share/virtualenvs/fumes-JfS6j1s-/lib/python3.7/site-packages/scipy/optimize/_trustregion_constr/minimize_trustregion_constr.py in _minimize_trustregion_constr(fun, x0, args, grad, hess, hessp, bounds, constraints, xtol, gtol, barrier_tol, sparse_jacobian, callback, maxiter, verbose, finite_diff_rel_step, initial_constr_penalty, initial_tr_radius, initial_barrier_parameter, initial_barrier_tolerance, factorization_method, disp)
#     518             initial_barrier_tolerance,
#     519             initial_constr_penalty, initial_tr_radius,
# --> 520             factorization_method)
#     521
#     522     # Status 3 occurs when the callback function requests termination,
#
# ~/.local/share/virtualenvs/fumes-JfS6j1s-/lib/python3.7/site-packages/scipy/optimize/_trustregion_constr/tr_interior_point.py in tr_interior_point(fun, grad, lagr_hess, n_vars, n_ineq, n_eq, constr, jac, x0, fun0, grad0, constr_ineq0, jac_ineq0, constr_eq0, jac_eq0, stop_criteria, enforce_feasibility, xtol, state, initial_barrier_parameter, initial_tolerance, initial_penalty, initial_trust_radius, factorization_method)
#     326             constr0_subprob, jac0_subprob, subprob.stop_criteria,
#     327             state, initial_penalty, trust_radius,
# --> 328             factorization_method, trust_lb, trust_ub, subprob.scaling)
#     329         if subprob.terminate:
#     330             break
#
# ~/.local/share/virtualenvs/fumes-JfS6j1s-/lib/python3.7/site-packages/scipy/optimize/_trustregion_constr/equality_constrained_sqp.py in equality_constrained_sqp(fun_and_constr, grad_and_jac, lagr_hess, x0, fun0, grad0, constr0, jac0, stop_criteria, state, initial_penalty, initial_trust_radius, factorization_method, trust_lb, trust_ub, scaling)
#     145         # Evaluate function and constraints at trial point
#     146         x_next = x + S.dot(d)
# --> 147         f_next, b_next = fun_and_constr(x_next)
#     148         # Compute merit function at trial point
#     149         merit_function_next = f_next + penalty*norm(b_next)
#
# ~/.local/share/virtualenvs/fumes-JfS6j1s-/lib/python3.7/site-packages/scipy/optimize/_trustregion_constr/tr_interior_point.py in function_and_constraints(self, z)
#      81         # Compute function and constraints
#      82         f = self.fun(x)
# ---> 83         c_eq, c_ineq = self.constr(x)
#      84         # Return objective function and constraints
#      85         return (self._compute_function(f, c_ineq, s),
#
# ~/.local/share/virtualenvs/fumes-JfS6j1s-/lib/python3.7/site-packages/scipy/optimize/_trustregion_constr/canonical_constraint.py in fun(x)
#     102             if canonical_constraints:
#     103                 eq_all, ineq_all = zip(
# --> 104                         *[c.fun(x) for c in canonical_constraints])
#     105             else:
#     106                 eq_all, ineq_all = [], []
#
# ~/.local/share/virtualenvs/fumes-JfS6j1s-/lib/python3.7/site-packages/scipy/optimize/_trustregion_constr/canonical_constraint.py in <listcomp>(.0)
#     102             if canonical_constraints:
#     103                 eq_all, ineq_all = zip(
# --> 104                         *[c.fun(x) for c in canonical_constraints])
#     105             else:
#     106                 eq_all, ineq_all = [], []
#
# ~/.local/share/virtualenvs/fumes-JfS6j1s-/lib/python3.7/site-packages/scipy/optimize/_trustregion_constr/canonical_constraint.py in fun(x)
#     236         if np.all(finite_lb):
#     237             def fun(x):
# --> 238                 return empty_fun, lb - cfun.fun(x)
#     239
#     240             def jac(x):
#
# ~/.local/share/virtualenvs/fumes-JfS6j1s-/lib/python3.7/site-packages/scipy/optimize/_differentiable_functions.py in fun(self, x)
#     514
#     515     def fun(self, x):
# --> 516         self._update_x(x)
#     517         self._update_fun()
#     518         return self.f
#
# ~/.local/share/virtualenvs/fumes-JfS6j1s-/lib/python3.7/site-packages/scipy/optimize/_differentiable_functions.py in _update_x(self, x)
#     496     def _update_x(self, x):
#     497         if not np.array_equal(x, self.x):
# --> 498             self._update_x_impl(x)
#     499
#     500     def _update_fun(self):
#
# ~/.local/share/virtualenvs/fumes-JfS6j1s-/lib/python3.7/site-packages/scipy/optimize/_differentiable_functions.py in update_x(x)
#     479                 self.J_updated = False
#     480                 self.H_updated = False
# --> 481                 self._update_hess()
#     482         else:
#     483             def update_x(x):
#
# ~/.local/share/virtualenvs/fumes-JfS6j1s-/lib/python3.7/site-packages/scipy/optimize/_differentiable_functions.py in _update_hess(self)
#     510     def _update_hess(self):
#     511         if not self.H_updated:
# --> 512             self._update_hess_impl()
#     513             self.H_updated = True
#     514
#
# ~/.local/share/virtualenvs/fumes-JfS6j1s-/lib/python3.7/site-packages/scipy/optimize/_differentiable_functions.py in update_hess()
#     460
#     461             def update_hess():
# --> 462                 self._update_jac()
#     463                 # When v is updated before x was updated, then x_prev and
#     464                 # J_prev are None and we need this check.
#
# ~/.local/share/virtualenvs/fumes-JfS6j1s-/lib/python3.7/site-packages/scipy/optimize/_differentiable_functions.py in _update_jac(self)
#     505     def _update_jac(self):
#     506         if not self.J_updated:
# --> 507             self._update_jac_impl()
#     508             self.J_updated = True
#     509
#
# ~/.local/share/virtualenvs/fumes-JfS6j1s-/lib/python3.7/site-packages/scipy/optimize/_differentiable_functions.py in update_jac()
#     409                     self.J = np.atleast_2d(
#     410                         approx_derivative(fun_wrapped, self.x, f0=self.f,
# --> 411                                           **finite_diff_options))
#     412                 self.J = np.atleast_2d(self.J)
#     413                 self.sparse_jacobian = False
#
# ~/.local/share/virtualenvs/fumes-JfS6j1s-/lib/python3.7/site-packages/scipy/optimize/_numdiff.py in approx_derivative(fun, x0, method, rel_step, abs_step, f0, bounds, sparsity, as_linear_operator, args, kwargs)
#     485         if sparsity is None:
#     486             return _dense_difference(fun_wrapped, x0, f0, h,
# --> 487                                      use_one_sided, method)
#     488         else:
#     489             if not issparse(sparsity) and len(sparsity) == 2:
#
# ~/.local/share/virtualenvs/fumes-JfS6j1s-/lib/python3.7/site-packages/scipy/optimize/_numdiff.py in _dense_difference(fun, x0, f0, h, use_one_sided, method)
#     555             x = x0 + h_vecs[i]
#     556             dx = x[i] - x0[i]  # Recompute dx as exactly representable number.
# --> 557             df = fun(x) - f0
#     558         elif method == '3-point' and use_one_sided[i]:
#     559             x1 = x0 + h_vecs[i]
#
# ~/.local/share/virtualenvs/fumes-JfS6j1s-/lib/python3.7/site-packages/scipy/optimize/_numdiff.py in fun_wrapped(x)
#     435
#     436     def fun_wrapped(x):
# --> 437         f = np.atleast_1d(fun(x, *args, **kwargs))
#     438         if f.ndim > 1:
#     439             raise RuntimeError("`fun` return value has "
#
# ~/.local/share/virtualenvs/fumes-JfS6j1s-/lib/python3.7/site-packages/scipy/optimize/_differentiable_functions.py in fun_wrapped(x)
#     339         def fun_wrapped(x):
#     340             self.nfev += 1
# --> 341             return np.atleast_1d(fun(x))
#     342
#     343         def update_fun():
#
# ~/content/rrg/src/planning/fumes/fumes/planner/utils.py in <lambda>(theta)
#     118         return [
#     119             NonlinearConstraint(
# --> 120                 fun=lambda theta: traj_generator(*theta).xmin,
#     121                 jac="2-point",
#     122                 lb=limits[0],
#
# ~/content/rrg/src/planning/fumes/fumes/planner/trajectory_gen.py in generate(self, lh, lw, orientation, origin_x, origin_y)
#      87                                       origin=(origin_x, origin_y),
#      88                                       start_point=self.start_point,
# ---> 89                                       altitude=self.alt)
#      90         elif self.traj_type == "spiral":
#      91             return SpiralWithStart(self.t0, self.vel, self.lh, self.lw,
#
# ~/content/rrg/src/planning/fumes/fumes/trajectory/lawnmower_with_start.py in __init__(self, t0, vel, lh, lw, resolution, altitude, origin, orientation, start_point, noise)
#      53             self.start_point = start_point
#      54
# ---> 55         self._create_global_frame()
#      56
#      57         self._length = None
#
# ~/content/rrg/src/planning/fumes/fumes/trajectory/lawnmower_with_start.py in _create_global_frame(self)
#      67
#      68         all_coords_x = np.hstack(
# ---> 69             [np.array([self.start_point[0], self.origin[0]]), self.path.xy[0]])
#      70         all_coords_y = np.hstack(
#      71             [np.array([self.start_point[1], self.origin[1]]), self.path.xy[1]])
#
# ~/.local/share/virtualenvs/fumes-JfS6j1s-/lib/python3.7/site-packages/shapely/geometry/linestring.py in xy(self)
#     143           [0.0, 1.0]
#     144         """
# --> 145         return self.coords.xy
#     146
#     147     def parallel_offset(
#
# ~/.local/share/virtualenvs/fumes-JfS6j1s-/lib/python3.7/site-packages/shapely/coords.py in xy(self)
#     174             x.append(temp.value)
#     175             lgeos.GEOSCoordSeq_getY(self._cseq, i, byref(temp))
# --> 176             y.append(temp.value)
#     177         return x, y
#     178
#
# KeyboardInterrupt:

# %% [markdown]
# Getting trajectory...
# Planning chain 0 of 12 at time 0.0
# Adding budget constraint.
# Adding safety boundary constraint.
# Adding parameter bounds constraint.
# n:1	 Value:-17847783.77358003
# -elapsed time: 0.131 (s)
# n:2	 Value:-17847783.77358003
# -elapsed time: 0.124 (s)
# n:3	 Value:-17847783.77358003
# -elapsed time: 0.12 (s)
# n:4	 Value:-17847783.77358003
# -elapsed time: 0.118 (s)
# n:6	 Value:-17847783.77358003
# -elapsed time: 0.131 (s)
# n:7	 Value:-17847783.77358003
# -elapsed time: 0.114 (s)
# n:8	 Value:-17847783.77358003
# -elapsed time: 0.113 (s)
# n:9	 Value:-17847783.77358003
# -elapsed time: 0.113 (s)
# n:11	 Value:-17847783.77358003
# -elapsed time: 0.116 (s)
# n:12	 Value:-17848865.00225035
# -elapsed time: 0.137 (s)
# n:13	 Value:-17848973.41266882
# -elapsed time: 0.131 (s)

# %%
# Create the robot
rob = OfflineRobot(model, plan_opt, environment, vel, com_window)

# Create the simulator
simulator = Simulator(rob, environment)

# Run the simulator
times = np.arange(0, duration + 1)
simulator.simulate(times, experiment_name=experiment_name)

# Plot outcomes
simulator.plot_comms()
simulator.plot_all()

# %%
simulator.plot_world()
# Out:
# Generating global simulation.
# -elapsed time: 808 (s)
